# %%
import pandas as pd  #For data loading, manipulation, and analysis.
import matplotlib as plt # For creating a wide variety of static, animated, and interactive plots.
import seaborn as sns #For making statistical plots more attractive and informative.
# %matplotlib inline

# %%
match_data = pd.read_csv('ODI_Match_data.csv')
match_info = pd.read_csv('ODI_Match_info.csv')
# Out:
# C:\Users\ravin\AppData\Local\Temp\ipykernel_16512\3395173314.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   match_data = pd.read_csv('ODI_Match_data.csv')

# %%
match_data.head()
# Out:
#    match_id   season  start_date                           venue  innings  \
# 0   1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore        1
# 1   1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore        1
# 2   1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore        1
# 3   1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore        1
# 4   1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore        1
#
#    ball batting_team bowling_team     striker   non_striker  ... wides  \
# 0   0.1        India    Australia  RD Gaikwad  Shubman Gill  ...   NaN
# 1   0.2        India    Australia  RD Gaikwad  Shubman Gill  ...   NaN
# 2   0.3        India    Australia  RD Gaikwad  Shubman Gill  ...   NaN
# 3   0.4        India    Australia  RD Gaikwad  Shubman Gill  ...   NaN
# 4   0.5        India    Australia  RD Gaikwad  Shubman Gill  ...   NaN
#
#    noballs  byes  legbyes  penalty  wicket_type  player_dismissed  \
# ...

# %%
print(match_data.shape)
print(match_info.shape)
# Out:
# (1265103, 23)
# (2379, 18)

# %%
match_data.head()
# Out:
#    match_id   season  start_date                           venue  innings  \
# 0   1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore        1
# 1   1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore        1
# 2   1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore        1
# 3   1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore        1
# 4   1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore        1
#
#    ball batting_team bowling_team     striker   non_striker  ... wides  \
# 0   0.1        India    Australia  RD Gaikwad  Shubman Gill  ...   NaN
# 1   0.2        India    Australia  RD Gaikwad  Shubman Gill  ...   NaN
# 2   0.3        India    Australia  RD Gaikwad  Shubman Gill  ...   NaN
# 3   0.4        India    Australia  RD Gaikwad  Shubman Gill  ...   NaN
# 4   0.5        India    Australia  RD Gaikwad  Shubman Gill  ...   NaN
#
#    noballs  byes  legbyes  penalty  wicket_type  player_dismissed  \
# ...

# %%
match_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1265103 entries, 0 to 1265102
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   match_id                1265103 non-null  int64
#  1   season                  1265103 non-null  object
#  2   start_date              1265103 non-null  object
#  3   venue                   1265103 non-null  object
#  4   innings                 1265103 non-null  int64
#  5   ball                    1265103 non-null  float64
#  6   batting_team            1265103 non-null  object
#  7   bowling_team            1265103 non-null  object
#  8   striker                 1265103 non-null  object
#  9   non_striker             1265103 non-null  object
#  10  bowler                  1265103 non-null  object
#  11  runs_off_bat            1265103 non-null  int64
#  12  extras                  1265103 non-null  int64
# ...

# %%
match_data[match_data['wides'].isna()]
# Out:
#          match_id   season  start_date                           venue  \
# 0         1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore
# 1         1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore
# 2         1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore
# 3         1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore
# 4         1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore
# ...           ...      ...         ...                             ...
# 1265098     64814  2002/03  2002-12-29             McLean Park, Napier
# 1265099     64814  2002/03  2002-12-29             McLean Park, Napier
# 1265100     64814  2002/03  2002-12-29             McLean Park, Napier
# 1265101     64814  2002/03  2002-12-29             McLean Park, Napier
# 1265102     64814  2002/03  2002-12-29             McLean Park, Napier
#
#          innings  ball batting_team bowling_team     striker   non_striker  \
# ...

# %%
match_data['wides'] = match_data['wides'].fillna(0).astype('int64')
match_data['noballs'] = match_data['noballs'].fillna(0).astype('int64')
match_data['byes'] = match_data['byes'].fillna(0).astype('int64')
match_data['legbyes'] = match_data['legbyes'].fillna(0).astype('int64')
match_data['penalty'] = match_data['penalty'].fillna(0).astype('int64')

# %%
match_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1265103 entries, 0 to 1265102
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   match_id                1265103 non-null  int64
#  1   season                  1265103 non-null  object
#  2   start_date              1265103 non-null  object
#  3   venue                   1265103 non-null  object
#  4   innings                 1265103 non-null  int64
#  5   ball                    1265103 non-null  float64
#  6   batting_team            1265103 non-null  object
#  7   bowling_team            1265103 non-null  object
#  8   striker                 1265103 non-null  object
#  9   non_striker             1265103 non-null  object
#  10  bowler                  1265103 non-null  object
#  11  runs_off_bat            1265103 non-null  int64
#  12  extras                  1265103 non-null  int64
# ...

# %%
match_data.iloc[0]
# Out:
# match_id                                         1389389
# season                                           2023/24
# start_date                                    2023-09-24
# venue                     Holkar Cricket Stadium, Indore
# innings                                                1
# ball                                                 0.1
# batting_team                                       India
# bowling_team                                   Australia
# striker                                       RD Gaikwad
# non_striker                                 Shubman Gill
# bowler                                        SH Johnson
# runs_off_bat                                           4
# extras                                                 0
# wides                                                  0
# noballs                                                0
# byes                                                   0
# ...

# %%
match_data[match_data['wides']==0]
# Out:
#          match_id   season  start_date                           venue  \
# 0         1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore
# 1         1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore
# 2         1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore
# 3         1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore
# 4         1389389  2023/24  2023-09-24  Holkar Cricket Stadium, Indore
# ...           ...      ...         ...                             ...
# 1265098     64814  2002/03  2002-12-29             McLean Park, Napier
# 1265099     64814  2002/03  2002-12-29             McLean Park, Napier
# 1265100     64814  2002/03  2002-12-29             McLean Park, Napier
# 1265101     64814  2002/03  2002-12-29             McLean Park, Napier
# 1265102     64814  2002/03  2002-12-29             McLean Park, Napier
#
#          innings  ball batting_team bowling_team     striker   non_striker  \
# ...

# %%
total_runs = ['runs_off_bat', 'extras', 'wides', 'noballs', 'byes', 'legbyes', 'penalty']
match_data['total_runs'] = match_data['runs_off_bat'] + match_data['extras'] + match_data['wides'] + match_data['noballs'] + match_data['byes'] + match_data['legbyes'] + match_data['penalty']

# %%
match_data.loc[552]
# Out:
# match_id                                   1336129
# season                                        2023
# start_date                              2023-09-23
# venue                     Trent Bridge, Nottingham
# innings                                          1
# ball                                          10.6
# batting_team                               England
# bowling_team                               Ireland
# striker                                 BM Duckett
# non_striker                               WG Jacks
# bowler                                    CA Young
# runs_off_bat                                     0
# extras                                           0
# wides                                            0
# noballs                                          0
# byes                                             0
# legbyes                                          0
# penalty                                          0
# ...

# %%
total_score_df = match_data.groupby(['match_id', 'innings'])['total_runs'].sum().reset_index()
total_score_df
# Out:
#       match_id  innings  total_runs
# 0        64814        1         282
# 1        64814        2         236
# 2        64815        1         130
# 3        64815        2         125
# 4        64816        1         140
# ...        ...      ...         ...
# 4696   1390346        1         285
# 4697   1390346        2         223
# 4698   1395700        1         144
# 4699   1395701        1         266
# 4700   1395701        2         176
#
# [4701 rows x 3 columns]

# %%
total_score_df=total_score_df[total_score_df['innings']==1]

# %%
total_score_df
# Out:
#       match_id  innings  total_runs
# 0        64814        1         282
# 2        64815        1         130
# 4        64816        1         140
# 6        64817        1         188
# 8        64819        1         136
# ...        ...      ...         ...
# 4692   1390344        1         219
# 4694   1390345        1         318
# 4696   1390346        1         285
# 4698   1395700        1         144
# 4699   1395701        1         266
#
# [2379 rows x 3 columns]

# %%
match_df = match_info.merge(total_score_df[['match_id','total_runs']], left_on = 'id' , right_on = 'match_id')
match_df
# Out:
#            id   season          city        date        team1        team2  \
# 0     1389389  2023/24        Indore  2023/09/24        India    Australia
# 1     1336129     2023    Nottingham  2023/09/23      England      Ireland
# 2     1395701     2023         Dhaka  2023/09/23  New Zealand   Bangladesh
# 3     1389388  2023/24    Chandigarh  2023/09/22    Australia        India
# 4     1395700     2023         Dhaka  2023/09/21  New Zealand   Bangladesh
# ...       ...      ...           ...         ...          ...          ...
# 2374    65634  2002/03        Sydney  2003/01/09    Sri Lanka    Australia
# 2375    64817  2002/03    Wellington  2003/01/08  New Zealand        India
# 2376    64816  2002/03    Queenstown  2003/01/04        India  New Zealand
# 2377    64815  2002/03  Christchurch  2003/01/01        India  New Zealand
# 2378    64814  2002/03        Napier  2002/12/29  New Zealand        India
#
# ...

# %%
match_df["team1"].unique()
# Out:
# array(['India', 'England', 'New Zealand', 'Australia', 'Sri Lanka',
#        'South Africa', 'Bangladesh', 'Pakistan', 'Nepal', 'Afghanistan',
#        'West Indies', 'Scotland', 'United Arab Emirates', 'Oman',
#        'Netherlands', 'Zimbabwe', 'United States of America', 'Ireland',
#        'Canada', 'Namibia', 'Jersey', 'Papua New Guinea', 'Hong Kong',
#        'Kenya', 'Africa XI', 'Bermuda'], dtype=object)

# %%
match_df["team2"].unique()
# Out:
# array(['Australia', 'Ireland', 'Bangladesh', 'India', 'New Zealand',
#        'Sri Lanka', 'Pakistan', 'South Africa', 'Afghanistan', 'Nepal',
#        'West Indies', 'Netherlands', 'United States of America',
#        'Zimbabwe', 'Oman', 'Scotland', 'United Arab Emirates',
#        'Papua New Guinea', 'Jersey', 'Canada', 'Namibia', 'England',
#        'Hong Kong', 'Kenya', 'Bermuda', 'Asia XI', 'ICC World XI'],
#       dtype=object)

# %%
match_df["team1"].value_counts()
# Out:
# team1
# Australia                   254
# India                       252
# England                     225
# Sri Lanka                   192
# Bangladesh                  191
# New Zealand                 182
# South Africa                172
# West Indies                 172
# Zimbabwe                    144
# Pakistan                    139
# Ireland                      83
# Afghanistan                  66
# Scotland                     50
# United Arab Emirates         47
# Netherlands                  26
# Kenya                        25
# Canada                       24
# Papua New Guinea             23
# Namibia                      23
# United States of America     22
# Oman                         22
# Nepal                        21
# Hong Kong                    10
# Bermuda                       7
# Africa XI                     5
# Jersey                        2
# Name: count, dtype: int64

# %%
teams = [
    'India',
    'England',
    'New Zealand',
    'Australia',
    'Sri Lanka',
    'South Africa',
    'Bangladesh',
    'Pakistan',
    'Afghanistan',
    'Netherlands'
]

# %%
match_df = match_df[match_df['team1'].isin(teams)]
match_df = match_df[match_df['team2'].isin(teams)]

# %%
match_df
# Out:
#            id   season          city        date        team1        team2  \
# 0     1389389  2023/24        Indore  2023/09/24        India    Australia
# 2     1395701     2023         Dhaka  2023/09/23  New Zealand   Bangladesh
# 3     1389388  2023/24    Chandigarh  2023/09/22    Australia        India
# 4     1395700     2023         Dhaka  2023/09/21  New Zealand   Bangladesh
# 5     1388414     2023       Colombo  2023/09/17    Sri Lanka        India
# ...       ...      ...           ...         ...          ...          ...
# 2374    65634  2002/03        Sydney  2003/01/09    Sri Lanka    Australia
# 2375    64817  2002/03    Wellington  2003/01/08  New Zealand        India
# 2376    64816  2002/03    Queenstown  2003/01/04        India  New Zealand
# 2377    64815  2002/03  Christchurch  2003/01/01        India  New Zealand
# 2378    64814  2002/03        Napier  2002/12/29  New Zealand        India
#
# ...

# %%
match_df['dl_applied'].value_counts()
# Out:
# dl_applied
# 0    1219
# 1     109
# Name: count, dtype: int64

# %%
match_df = match_df[match_df['dl_applied'] == 0]
match_df
# Out:
#            id   season          city        date         team1        team2  \
# 2     1395701     2023         Dhaka  2023/09/23   New Zealand   Bangladesh
# 3     1389388  2023/24    Chandigarh  2023/09/22     Australia        India
# 4     1395700     2023         Dhaka  2023/09/21   New Zealand   Bangladesh
# 5     1388414     2023       Colombo  2023/09/17     Sri Lanka        India
# 6     1373575  2023/24  Johannesburg  2023/09/17  South Africa    Australia
# ...       ...      ...           ...         ...           ...          ...
# 2374    65634  2002/03        Sydney  2003/01/09     Sri Lanka    Australia
# 2375    64817  2002/03    Wellington  2003/01/08   New Zealand        India
# 2376    64816  2002/03    Queenstown  2003/01/04         India  New Zealand
# 2377    64815  2002/03  Christchurch  2003/01/01         India  New Zealand
# 2378    64814  2002/03        Napier  2002/12/29   New Zealand        India
#
# ...

# %%
match_df.isnull().sum()
# Out:
# id                   0
# season               0
# city               177
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner              67
# win_by_runs          0
# win_by_wickets       0
# player_of_match     60
# venue                0
# umpire1              0
# umpire2              0
# umpire3              5
# match_id             0
# total_runs           0
# dtype: int64

# %%
match_df['city'].value_counts()
# Out:
# city
# Colombo       72
# London        63
# Mirpur        58
# Abu Dhabi     33
# Centurion     31
#               ..
# Faisalabad     1
# Jamshedpur     1
# Canterbury     1
# Peshawar       1
# Multan         1
# Name: count, Length: 106, dtype: int64

# %%
match_df[match_df['city'].isnull()]
match_df
# Out:
#            id   season          city        date         team1        team2  \
# 2     1395701     2023         Dhaka  2023/09/23   New Zealand   Bangladesh
# 3     1389388  2023/24    Chandigarh  2023/09/22     Australia        India
# 4     1395700     2023         Dhaka  2023/09/21   New Zealand   Bangladesh
# 5     1388414     2023       Colombo  2023/09/17     Sri Lanka        India
# 6     1373575  2023/24  Johannesburg  2023/09/17  South Africa    Australia
# ...       ...      ...           ...         ...           ...          ...
# 2374    65634  2002/03        Sydney  2003/01/09     Sri Lanka    Australia
# 2375    64817  2002/03    Wellington  2003/01/08   New Zealand        India
# 2376    64816  2002/03    Queenstown  2003/01/04         India  New Zealand
# 2377    64815  2002/03  Christchurch  2003/01/01         India  New Zealand
# 2378    64814  2002/03        Napier  2002/12/29   New Zealand        India
#
# ...

# %%
match_df['city']= match_df['city'].fillna('Unknown')
# Out:
# C:\Users\ravin\AppData\Local\Temp\ipykernel_16512\985340321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   match_df['city']= match_df['city'].fillna('Unknown')

# %%
match_df.isnull().sum()
# Out:
# id                  0
# season              0
# city                0
# date                0
# team1               0
# team2               0
# toss_winner         0
# toss_decision       0
# result              0
# dl_applied          0
# winner             67
# win_by_runs         0
# win_by_wickets      0
# player_of_match    60
# venue               0
# umpire1             0
# umpire2             0
# umpire3             5
# match_id            0
# total_runs          0
# dtype: int64

# %%
match_df[match_df['winner'].isnull()]
# Out:
#            id   season          city        date         team1         team2  \
# 4     1395700     2023         Dhaka  2023/09/21   New Zealand    Bangladesh
# 24    1388394     2023         Kandy  2023/09/02         India      Pakistan
# 161   1322280  2022/23  Christchurch  2022/11/30         India   New Zealand
# 163   1322279  2022/23      Hamilton  2022/11/27         India   New Zealand
# 164   1340533  2022/23         Kandy  2022/11/27   Afghanistan     Sri Lanka
# ...       ...      ...           ...         ...           ...           ...
# 2165    64928  2004/05        Durban  2005/02/11  South Africa       England
# 2170    64924  2004/05  Bloemfontein  2005/02/02       England  South Africa
# 2213    66375     2004    Amstelveen  2004/08/23     Australia         India
# 2276    66364  2003/04       Chennai  2003/10/23         India   New Zealand
# 2308    66356     2003         Dhaka  2003/04/21         India  South Africa
#
# ...

# %%
match_df = match_df[['match_id','city','winner','total_runs']]
match_df.shape
# Out:
# (1219, 4)

# %%
df_match = match_df.merge(match_data, on='match_id')
df_match
# Out:
#         match_id    city       winner  total_runs_x   season  start_date  \
# 0        1395701   Dhaka  New Zealand           266     2023  2023-09-23
# 1        1395701   Dhaka  New Zealand           266     2023  2023-09-23
# 2        1395701   Dhaka  New Zealand           266     2023  2023-09-23
# 3        1395701   Dhaka  New Zealand           266     2023  2023-09-23
# 4        1395701   Dhaka  New Zealand           266     2023  2023-09-23
# ...          ...     ...          ...           ...      ...         ...
# 660345     64814  Napier  New Zealand           282  2002/03  2002-12-29
# 660346     64814  Napier  New Zealand           282  2002/03  2002-12-29
# 660347     64814  Napier  New Zealand           282  2002/03  2002-12-29
# 660348     64814  Napier  New Zealand           282  2002/03  2002-12-29
# 660349     64814  Napier  New Zealand           282  2002/03  2002-12-29
#
#                                         venue  innings  ball batting_team  \
# ...

# %%
df_match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660350 entries, 0 to 660349
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   match_id                660350 non-null  int64
#  1   city                    660350 non-null  object
#  2   winner                  642359 non-null  object
#  3   total_runs_x            660350 non-null  int64
#  4   season                  660350 non-null  object
#  5   start_date              660350 non-null  object
#  6   venue                   660350 non-null  object
#  7   innings                 660350 non-null  int64
#  8   ball                    660350 non-null  float64
#  9   batting_team            660350 non-null  object
#  10  bowling_team            660350 non-null  object
#  11  striker                 660350 non-null  object
#  12  non_striker             660350 non-null  object
#  13  bowler                  660350 non-null  object
# ...

# %%
df_match['batting_team'].unique()
# Out:
# array(['New Zealand', 'Bangladesh', 'Australia', 'India', 'Sri Lanka',
#        'South Africa', 'England', 'Pakistan', 'Afghanistan',
#        'Netherlands'], dtype=object)

# %%
df_match['bowling_team'].unique()
# Out:
# array(['Bangladesh', 'New Zealand', 'India', 'Australia', 'Sri Lanka',
#        'South Africa', 'England', 'Pakistan', 'Afghanistan',
#        'Netherlands'], dtype=object)

# %%
df_match = df_match[df_match['innings'] == 2]
df_match.shape
# Out:
# (304840, 27)

# %%
df_match.head()
# Out:
#      match_id   city       winner  total_runs_x season  start_date  \
# 303   1395701  Dhaka  New Zealand           266   2023  2023-09-23
# 304   1395701  Dhaka  New Zealand           266   2023  2023-09-23
# 305   1395701  Dhaka  New Zealand           266   2023  2023-09-23
# 306   1395701  Dhaka  New Zealand           266   2023  2023-09-23
# 307   1395701  Dhaka  New Zealand           266   2023  2023-09-23
#
#                                      venue  innings  ball batting_team  ...  \
# 303  Shere Bangla National Stadium, Mirpur        2   0.1   Bangladesh  ...
# 304  Shere Bangla National Stadium, Mirpur        2   0.2   Bangladesh  ...
# 305  Shere Bangla National Stadium, Mirpur        2   0.3   Bangladesh  ...
# 306  Shere Bangla National Stadium, Mirpur        2   0.4   Bangladesh  ...
# 307  Shere Bangla National Stadium, Mirpur        2   0.5   Bangladesh  ...
#
#     noballs byes legbyes penalty  wicket_type  player_dismissed  \
# ...

# %%
df_match['over'] = df_match['ball'].apply(lambda x:str(x).split(".")[0])
df_match['ball_no'] = df_match['ball'].apply(lambda x:str(x).split(".")[1])
# Out:
# C:\Users\ravin\AppData\Local\Temp\ipykernel_16512\2294556516.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_match['over'] = df_match['ball'].apply(lambda x:str(x).split(".")[0])
# C:\Users\ravin\AppData\Local\Temp\ipykernel_16512\2294556516.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_match['ball_no'] = df_match['ball'].apply(lambda x:str(x).split(".")[1])

# %%
df_match.head(10)
# Out:
#      match_id   city       winner  total_runs_x season  start_date  \
# 303   1395701  Dhaka  New Zealand           266   2023  2023-09-23
# 304   1395701  Dhaka  New Zealand           266   2023  2023-09-23
# 305   1395701  Dhaka  New Zealand           266   2023  2023-09-23
# 306   1395701  Dhaka  New Zealand           266   2023  2023-09-23
# 307   1395701  Dhaka  New Zealand           266   2023  2023-09-23
# 308   1395701  Dhaka  New Zealand           266   2023  2023-09-23
# 309   1395701  Dhaka  New Zealand           266   2023  2023-09-23
# 310   1395701  Dhaka  New Zealand           266   2023  2023-09-23
# 311   1395701  Dhaka  New Zealand           266   2023  2023-09-23
# 312   1395701  Dhaka  New Zealand           266   2023  2023-09-23
#
#                                      venue  innings  ball batting_team  ...  \
# 303  Shere Bangla National Stadium, Mirpur        2   0.1   Bangladesh  ...
# ...

# %%
df_match.columns
# Out:
# Index(['match_id', 'city', 'winner', 'total_runs_x', 'season', 'start_date',
#        'venue', 'innings', 'ball', 'batting_team', 'bowling_team', 'striker',
#        'non_striker', 'bowler', 'runs_off_bat', 'extras', 'wides', 'noballs',
#        'byes', 'legbyes', 'penalty', 'wicket_type', 'player_dismissed',
#        'other_wicket_type', 'other_player_dismissed', 'cricsheet_id',
#        'total_runs_y', 'over', 'ball_no'],
#       dtype='object')

# %%
df_match['balls_bowled'] = df_match['over'].astype(int)*6 + df_match['ball_no'].astype(int)
df_match['balls_left'] = 300 - df_match['balls_bowled']
df_match['balls_left'] = df_match['balls_left'].apply(lambda x:0 if x<0 else x)
# Out:
# C:\Users\ravin\AppData\Local\Temp\ipykernel_16512\611058665.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_match['balls_bowled'] = df_match['over'].astype(int)*6 + df_match['ball_no'].astype(int)
# C:\Users\ravin\AppData\Local\Temp\ipykernel_16512\611058665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_match['balls_left'] = 300 - df_match['balls_bowled']
# C:\Users\ravin\AppData\Local\Temp\ipykernel_16512\611058665.py:3: SettingWithCopyWarning:
# ...

# %%
df_match
# Out:
#         match_id    city       winner  total_runs_x   season  start_date  \
# 303      1395701   Dhaka  New Zealand           266     2023  2023-09-23
# 304      1395701   Dhaka  New Zealand           266     2023  2023-09-23
# 305      1395701   Dhaka  New Zealand           266     2023  2023-09-23
# 306      1395701   Dhaka  New Zealand           266     2023  2023-09-23
# 307      1395701   Dhaka  New Zealand           266     2023  2023-09-23
# ...          ...     ...          ...           ...      ...         ...
# 660345     64814  Napier  New Zealand           282  2002/03  2002-12-29
# 660346     64814  Napier  New Zealand           282  2002/03  2002-12-29
# 660347     64814  Napier  New Zealand           282  2002/03  2002-12-29
# 660348     64814  Napier  New Zealand           282  2002/03  2002-12-29
# 660349     64814  Napier  New Zealand           282  2002/03  2002-12-29
#
#                                         venue  innings  ball batting_team  \
# ...

# %%
df_match.columns
# Out:
# Index(['match_id', 'city', 'winner', 'total_runs_x', 'season', 'start_date',
#        'venue', 'innings', 'ball', 'batting_team', 'bowling_team', 'striker',
#        'non_striker', 'bowler', 'runs_off_bat', 'extras', 'wides', 'noballs',
#        'byes', 'legbyes', 'penalty', 'wicket_type', 'player_dismissed',
#        'other_wicket_type', 'other_player_dismissed', 'cricsheet_id',
#        'total_runs_y', 'over', 'ball_no', 'balls_bowled', 'balls_left'],
#       dtype='object')

# %%
columns_to_drop = ['over', 'ball', 'ball_no', 'striker', 'non_striker', 'bowler', 'runs_off_bat', 'extras', 
                   'wides', 'noballs', 'byes', 'legbyes', 'penalty', 'cricsheet_id', 'ball_bowled']

# Keep only columns that are present in the DataFrame
columns_to_drop = [col for col in columns_to_drop if col in df_match.columns]

df_match.drop(columns=columns_to_drop, inplace=True)
# Out:
# C:\Users\ravin\AppData\Local\Temp\ipykernel_16512\281983203.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_match.drop(columns=columns_to_drop, inplace=True)

# %%
df_match
# Out:
#         match_id    city       winner  total_runs_x   season  start_date  \
# 303      1395701   Dhaka  New Zealand           266     2023  2023-09-23
# 304      1395701   Dhaka  New Zealand           266     2023  2023-09-23
# 305      1395701   Dhaka  New Zealand           266     2023  2023-09-23
# 306      1395701   Dhaka  New Zealand           266     2023  2023-09-23
# 307      1395701   Dhaka  New Zealand           266     2023  2023-09-23
# ...          ...     ...          ...           ...      ...         ...
# 660345     64814  Napier  New Zealand           282  2002/03  2002-12-29
# 660346     64814  Napier  New Zealand           282  2002/03  2002-12-29
# 660347     64814  Napier  New Zealand           282  2002/03  2002-12-29
# 660348     64814  Napier  New Zealand           282  2002/03  2002-12-29
# 660349     64814  Napier  New Zealand           282  2002/03  2002-12-29
#
#                                         venue  innings batting_team  \
# ...

# %%
df_match['innings'].value_counts()
# Out:
# innings
# 2    304840
# Name: count, dtype: int64

# %%
df_match['curr_score'] = df_match.groupby('match_id')['total_runs_y'].cumsum()
df_match
# Out:
# C:\Users\ravin\AppData\Local\Temp\ipykernel_16512\3214136634.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_match['curr_score'] = df_match.groupby('match_id')['total_runs_y'].cumsum()
#         match_id    city       winner  total_runs_x   season  start_date  \
# 303      1395701   Dhaka  New Zealand           266     2023  2023-09-23
# 304      1395701   Dhaka  New Zealand           266     2023  2023-09-23
# 305      1395701   Dhaka  New Zealand           266     2023  2023-09-23
# 306      1395701   Dhaka  New Zealand           266     2023  2023-09-23
# 307      1395701   Dhaka  New Zealand           266     2023  2023-09-23
# ...          ...     ...          ...           ...      ...         ...
# ...

# %%
df_match.drop(columns=['season', 'start_date', 'venue', 'innings', 'total_runs_y', 'wicket_type', 'other_wicket_type', 
                       'other_player_dismissed'], inplace=True)
# Out:
# C:\Users\ravin\AppData\Local\Temp\ipykernel_16512\2014105522.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_match.drop(columns=['season', 'start_date', 'venue', 'innings', 'total_runs_y', 'wicket_type', 'other_wicket_type',

# %%
df_match
# Out:
#         match_id    city       winner  total_runs_x batting_team bowling_team  \
# 303      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 304      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 305      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 306      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 307      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# ...          ...     ...          ...           ...          ...          ...
# 660345     64814  Napier  New Zealand           282        India  New Zealand
# 660346     64814  Napier  New Zealand           282        India  New Zealand
# 660347     64814  Napier  New Zealand           282        India  New Zealand
# 660348     64814  Napier  New Zealand           282        India  New Zealand
# 660349     64814  Napier  New Zealand           282        India  New Zealand
#
# ...

# %%
df_match.isnull().sum()
# Out:
# match_id                 0
# city                     0
# winner                3757
# total_runs_x             0
# batting_team             0
# bowling_team             0
# player_dismissed    296785
# balls_bowled             0
# balls_left               0
# curr_score               0
# dtype: int64

# %%
df_match['player_dismissed']= df_match['player_dismissed'].fillna('0')
df_match['player_dismissed']= df_match['player_dismissed'].apply(lambda x:0 if x == '0' else '1')
df_match['player_dismissed']= df_match['player_dismissed'].astype(int)
# Out:
# C:\Users\ravin\AppData\Local\Temp\ipykernel_16512\3234208872.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_match['player_dismissed']= df_match['player_dismissed'].fillna('0')
# C:\Users\ravin\AppData\Local\Temp\ipykernel_16512\3234208872.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_match['player_dismissed']= df_match['player_dismissed'].apply(lambda x:0 if x == '0' else '1')
# C:\Users\ravin\AppData\Local\Temp\ipykernel_16512\3234208872.py:3: SettingWithCopyWarning:
# ...

# %%
df_match
# Out:
#         match_id    city       winner  total_runs_x batting_team bowling_team  \
# 303      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 304      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 305      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 306      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 307      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# ...          ...     ...          ...           ...          ...          ...
# 660345     64814  Napier  New Zealand           282        India  New Zealand
# 660346     64814  Napier  New Zealand           282        India  New Zealand
# 660347     64814  Napier  New Zealand           282        India  New Zealand
# 660348     64814  Napier  New Zealand           282        India  New Zealand
# 660349     64814  Napier  New Zealand           282        India  New Zealand
#
# ...

# %%
df_match['wickets'] = df_match.groupby('match_id')['player_dismissed'].cumsum()
df_match['wickets_left'] = 10 - df_match['wickets']
# Out:
# C:\Users\ravin\AppData\Local\Temp\ipykernel_16512\2032494290.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_match['wickets'] = df_match.groupby('match_id')['player_dismissed'].cumsum()
# C:\Users\ravin\AppData\Local\Temp\ipykernel_16512\2032494290.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_match['wickets_left'] = 10 - df_match['wickets']

# %%
df_match
# Out:
#         match_id    city       winner  total_runs_x batting_team bowling_team  \
# 303      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 304      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 305      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 306      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 307      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# ...          ...     ...          ...           ...          ...          ...
# 660345     64814  Napier  New Zealand           282        India  New Zealand
# 660346     64814  Napier  New Zealand           282        India  New Zealand
# 660347     64814  Napier  New Zealand           282        India  New Zealand
# 660348     64814  Napier  New Zealand           282        India  New Zealand
# 660349     64814  Napier  New Zealand           282        India  New Zealand
#
# ...

# %%
df_match.isnull().sum()
# Out:
# match_id               0
# city                   0
# winner              3757
# total_runs_x           0
# batting_team           0
# bowling_team           0
# player_dismissed       0
# balls_bowled           0
# balls_left             0
# curr_score             0
# wickets                0
# wickets_left           0
# dtype: int64

# %%
final_df = df_match.dropna()
final_df.isna().sum()
# Out:
# match_id            0
# city                0
# winner              0
# total_runs_x        0
# batting_team        0
# bowling_team        0
# player_dismissed    0
# balls_bowled        0
# balls_left          0
# curr_score          0
# wickets             0
# wickets_left        0
# dtype: int64

# %%
final_df.drop(columns=['player_dismissed','wickets'], inplace=True)
final_df
# Out:
# C:\Users\ravin\AppData\Local\Temp\ipykernel_16512\518102770.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['player_dismissed','wickets'], inplace=True)
#         match_id    city       winner  total_runs_x batting_team bowling_team  \
# 303      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 304      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 305      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 306      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 307      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# ...          ...     ...          ...           ...          ...          ...
# ...

# %%
final_df['runs_left'] = final_df['total_runs_x'] - final_df['curr_score']
# Out:
# C:\Users\ravin\AppData\Local\Temp\ipykernel_16512\1299277277.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['runs_left'] = final_df['total_runs_x'] - final_df['curr_score']

# %%
final_df['crr'] = (final_df['curr_score']*6) / final_df['balls_bowled']
final_df
# Out:
# C:\Users\ravin\AppData\Local\Temp\ipykernel_16512\4205697203.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['crr'] = (final_df['curr_score']*6) / final_df['balls_bowled']
#         match_id    city       winner  total_runs_x batting_team bowling_team  \
# 303      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 304      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 305      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 306      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 307      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# ...

# %%
final_df['rrr'] = (final_df['runs_left']*6) / final_df['balls_left']
final_df
# Out:
# C:\Users\ravin\AppData\Local\Temp\ipykernel_16512\2120178365.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['rrr'] = (final_df['runs_left']*6) / final_df['balls_left']
#         match_id    city       winner  total_runs_x batting_team bowling_team  \
# 303      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 304      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 305      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 306      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 307      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# ...          ...     ...          ...           ...          ...          ...
# ...

# %%
final_df['winner'].unique()
# Out:
# array(['New Zealand', 'India', 'South Africa', 'Bangladesh', 'England',
#        'Australia', 'Sri Lanka', 'Pakistan', 'Afghanistan', 'Netherlands'],
#       dtype=object)

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
final_df['result']=final_df.apply(result,axis=1)
final_df
# Out:
# C:\Users\ravin\AppData\Local\Temp\ipykernel_16512\1595417604.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['result']=final_df.apply(result,axis=1)
#         match_id    city       winner  total_runs_x batting_team bowling_team  \
# 303      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 304      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 305      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 306      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# 307      1395701   Dhaka  New Zealand           266   Bangladesh  New Zealand
# ...          ...     ...          ...           ...          ...          ...
# ...

# %%
final_df['result'].value_counts()
# Out:
# result
# 0    153141
# 1    147942
# Name: count, dtype: int64

# %%
df = final_df[final_df['runs_left']>=0]
df.shape
# Out:
# (299247, 14)

# %%
df.head()
# Out:
#      match_id   city       winner  total_runs_x batting_team bowling_team  \
# 303   1395701  Dhaka  New Zealand           266   Bangladesh  New Zealand
# 304   1395701  Dhaka  New Zealand           266   Bangladesh  New Zealand
# 305   1395701  Dhaka  New Zealand           266   Bangladesh  New Zealand
# 306   1395701  Dhaka  New Zealand           266   Bangladesh  New Zealand
# 307   1395701  Dhaka  New Zealand           266   Bangladesh  New Zealand
#
#      balls_bowled  balls_left  curr_score  wickets_left  runs_left  crr  \
# 303             1         299           0            10        266  0.0
# 304             2         298           0            10        266  0.0
# 305             3         297           0            10        266  0.0
# 306             4         296           1            10        265  1.5
# 307             5         295           1            10        265  1.2
#
#           rrr  result
# 303  5.337793       0
# 304  5.355705       0
# ...

# %%
df.drop(columns=['match_id', 'winner', 'balls_bowled', 'curr_score'], inplace=True)
df
# Out:
# C:\Users\ravin\AppData\Local\Temp\ipykernel_16512\3492668609.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['match_id', 'winner', 'balls_bowled', 'curr_score'], inplace=True)
#           city  total_runs_x batting_team bowling_team  balls_left  \
# 303      Dhaka           266   Bangladesh  New Zealand         299
# 304      Dhaka           266   Bangladesh  New Zealand         298
# 305      Dhaka           266   Bangladesh  New Zealand         297
# 306      Dhaka           266   Bangladesh  New Zealand         296
# 307      Dhaka           266   Bangladesh  New Zealand         295
# ...        ...           ...          ...          ...         ...
# 660345  Napier           282        India  New Zealand          42
# ...

# %%
df.isnull().sum()
# Out:
# city            0
# total_runs_x    0
# batting_team    0
# bowling_team    0
# balls_left      0
# wickets_left    0
# runs_left       0
# crr             0
# rrr             1
# result          0
# dtype: int64

# %%
df[df['rrr'].isnull()]
# Out:
#            city  total_runs_x batting_team bowling_team  balls_left  \
# 178719  Kolkata           338        India      England           0
#
#         wickets_left  runs_left   crr  rrr  result
# 178719             1          0  6.76  NaN       0

# %%
df.dropna(inplace=True)
# Out:
# C:\Users\ravin\AppData\Local\Temp\ipykernel_16512\1379821321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# city            0
# total_runs_x    0
# batting_team    0
# bowling_team    0
# balls_left      0
# wickets_left    0
# runs_left       0
# crr             0
# rrr             0
# result          0
# dtype: int64

# %%
df.shape
# Out:
# (299246, 10)

# %%
df['city'].unique()
# Out:
# array(['Dhaka', 'Chandigarh', 'Colombo', 'Johannesburg', 'London',
#        'Centurion', 'Potchefstroom', 'Southampton', 'Bloemfontein',
#        'Cardiff', 'Lahore', 'Kandy', 'Hambantota', 'Chattogram', 'Harare',
#        'Bulawayo', 'Karachi', 'Rawalpindi', 'Benoni', 'Hamilton',
#        'Auckland', 'Chennai', 'Visakhapatnam', 'Mumbai', 'Kimberley',
#        'Indore', 'Raipur', 'Hyderabad', 'Thiruvananthapuram', 'Kolkata',
#        'Guwahati', 'Sydney', 'Adelaide', 'Delhi', 'Ranchi', 'Lucknow',
#        'Cairns', 'Rotterdam', 'Manchester', 'Chester-le-Street',
#        'Amstelveen', 'Mount Maunganui', 'Doha', 'Cape Town', 'Paarl',
#        'Birmingham', 'Pune', 'Wellington', 'Christchurch', 'Dunedin',
#        'Canberra', 'Unknown', 'Bengaluru', 'Rajkot', 'Leeds',
#        'Nottingham', 'Taunton', 'Bristol', 'Dubai', 'Abu Dhabi',
#        'Sharjah', 'Port Elizabeth', 'Nagpur', 'Napier', 'Durban',
#        'Melbourne', 'Nelson', 'Hobart', 'Brisbane', 'Dharamsala',
# ...

# %%
df = df.sample(df.shape[0])

# %%
df.sample()
# Out:
#               city  total_runs_x batting_team  bowling_team  balls_left  \
# 1922  Johannesburg           326    Australia  South Africa         180
#
#       wickets_left  runs_left  crr       rrr  result
# 1922             7        194  6.6  6.466667       0

# %%
df[df['balls_left']==0]
# Out:
#                  city  total_runs_x  batting_team bowling_team  balls_left  \
# 29897        Guwahati           379     Sri Lanka        India           0
# 138284     Wellington           245   New Zealand      England           0
# 91425          London           320  South Africa     Pakistan           0
# 104755          Dubai           284      Pakistan    Australia           0
# 591065        Colombo           297    Bangladesh    Sri Lanka           0
# ...               ...           ...           ...          ...         ...
# 315880  Potchefstroom           288  South Africa  New Zealand           0
# 418186         Jaipur           318  South Africa        India           0
# 107582          Delhi           276         India    Australia           0
# 440400      Centurion           334  South Africa      England           0
# 122526        Unknown           242  South Africa    Australia           0
#
#         wickets_left  runs_left       crr  rrr  result
# ...

# %%
df=df[df['balls_left'] != 0]
df.shape
# Out:
# (299133, 10)

# %%
X = df.drop(columns='result')
y = df['result']

# %%
X
# Out:
#                 city  total_runs_x  batting_team  bowling_team  balls_left  \
# 351644     Kimberley           309     Sri Lanka  South Africa          32
# 507723      Vadodara           168     Australia         India         234
# 389101     Bangalore           335         India   New Zealand         150
# 177869       Unknown           363      Pakistan     Australia         262
# 248462  Christchurch           225   New Zealand     Sri Lanka         226
# ...              ...           ...           ...           ...         ...
# 85492         London           331    Bangladesh      Pakistan          56
# 412256       Unknown           280     Sri Lanka         India          68
# 229651        Mirpur           346      Pakistan    Bangladesh         183
# 91314         London           320  South Africa      Pakistan         107
# 19342   Johannesburg           385   Netherlands  South Africa         191
#
#         wickets_left  runs_left       crr        rrr
# ...

# %%
y
# Out:
# 351644    1
# 507723    1
# 389101    1
# 177869    0
# 248462    1
#          ..
# 85492     0
# 412256    1
# 229651    0
# 91314     0
# 19342     0
# Name: result, Length: 299133, dtype: int64

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
X_train
# Out:
#                  city  total_runs_x  batting_team  bowling_team  balls_left  \
# 531845  Visakhapatnam           279         India     Sri Lanka         183
# 204581       Hamilton           261     Australia   New Zealand         148
# 224784        Unknown           273      Pakistan     Sri Lanka         109
# 498497      Cape Town           253  South Africa   New Zealand         139
# 466490        Karachi           230      Pakistan     Sri Lanka         237
# ...               ...           ...           ...           ...         ...
# 149807         Kanpur           345   New Zealand         India          41
# 277375       Fatullah           314      Pakistan     Sri Lanka          78
# 430745      Centurion           260       England  South Africa         104
# 206322       Auckland           318     Australia   New Zealand         160
# 533258         Margao           252         India     Sri Lanka         237
#
#         wickets_left  runs_left       crr       rrr
# ...

# %%
y_train
# Out:
# 531845    1
# 204581    0
# 224784    1
# 498497    1
# 466490    1
#          ..
# 149807    0
# 277375    0
# 430745    1
# 206322    0
# 533258    1
# Name: result, Length: 239306, dtype: int64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer(
    transformers=[
        ('trf', OneHotEncoder(sparse_output=False, drop='first'), ['batting_team', 'bowling_team', 'city'])
    ],
    remainder='passthrough'
)

# %%
X_train.head()
# Out:
#                  city  total_runs_x  batting_team bowling_team  balls_left  \
# 531845  Visakhapatnam           279         India    Sri Lanka         183
# 204581       Hamilton           261     Australia  New Zealand         148
# 224784        Unknown           273      Pakistan    Sri Lanka         109
# 498497      Cape Town           253  South Africa  New Zealand         139
# 466490        Karachi           230      Pakistan    Sri Lanka         237
#
#         wickets_left  runs_left       crr       rrr
# 531845             7        144  6.923077  4.721311
# 204581             6        137  4.894737  5.554054
# 224784             7        103  5.340314  5.669725
# 498497            10         74  6.670807  3.194245
# 466490            10        196  3.238095  4.962025

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(X_train, y_train)
# Out:
# c:\Users\ravin\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\compose\_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
# ...

# %%
y_pred=pipe.predict(X_test)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# Assuming 'pipe' is your trained pipeline
# pipe = Pipeline([('step1', trf), ('step2', LogisticRegression(solver='liblinear'))])

# Get feature names after transformation (if using ColumnTransformer)
# If 'trf' is a ColumnTransformer, you need to extract feature names correctly
try:
    # For ColumnTransformer, get feature names after transformation
    feature_names = pipe.named_steps['step1'].get_feature_names_out()
except AttributeError:
    # If 'step1' is a simple transformer (like StandardScaler), use original columns
    feature_names = X_train.columns  # Replace with your original feature names

# Get coefficients from LogisticRegression
coefficients = pipe.named_steps['step2'].coef_[0]  # For binary classification

# Create DataFrame for feature importance
feature_importance = pd.DataFrame({
    'feature': feature_names,
    'importance': coefficients
}).sort_values('importance', key=abs, ascending=False)  # Sort by absolute value of coefficients

# Plot top 20 features
plt.figure(figsize=(10, 6))
feature_importance.head(20).plot(x='feature', y='importance', kind='barh')
plt.title("Logistic Regression Feature Importance (Coefficients)")
plt.xlabel("Coefficient Value")
plt.ylabel("Feature")
plt.show()

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.859845888979892

# %%
pipe.predict_proba(X_test)[3]
# Out:
# array([9.99965106e-01, 3.48938945e-05])

# %%
import pickle
from sklearn.pipeline import Pipeline

# Assuming `pipe` is your pipeline
with open('model.pkl', 'wb') as file:
    pickle.dump(pipe, file)

# %%
print(pipe)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
from sklearn.metrics import precision_score

# Ensure y_pred and y_test are defined
precision = precision_score(y_test, y_pred)
print(f"Precision: {precision:.2f}")
# Out:
# Precision: 0.86

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.86

# %%
from sklearn.metrics import recall_score

recall = recall_score(y_test, y_pred)
print(f"Recall: {recall:.2f}")
# Out:
# Recall: 0.85

# %%
from sklearn.metrics import f1_score

f1 = f1_score(y_test, y_pred)
print(f"F1 Score: {f1:.2f}")
# Out:
# F1 Score: 0.86

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[26599  4081]
#  [ 4304 24843]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Loss", "Win"], yticklabels=["Loss", "Win"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
prev_bat = pd.read_csv('wc_23_bat.csv')
prev_bowl = pd.read_csv('wc_23_bowl.csv')
prev_bat.shape
prev_bowl.shape
# Out:
# (574, 15)

# %%
prev_bat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 875 entries, 0 to 874
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   player       875 non-null    object
#  1   dismissal    875 non-null    object
#  2   runs         875 non-null    int64
#  3   balls        875 non-null    int64
#  4   minutes      875 non-null    int64
#  5   4s           875 non-null    int64
#  6   6s           875 non-null    int64
#  7   strike_rate  875 non-null    float64
#  8   team         875 non-null    object
#  9   opponent     875 non-null    object
#  10  innings      875 non-null    int64
#  11  match_id     875 non-null    int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 82.2+ KB

# %%
prev_bat.head()
# Out:
#          player                  dismissal  runs  balls  minutes  4s  6s  \
# 0  Rohit Sharma               b Madushanka     4      2        2   1   0
# 1  Shubman Gill      c Mendis b Madushanka    92     92      136  11   2
# 2   Virat Kohli    c Nissanka b Madushanka    88     94      139  11   0
# 3  Shreyas Iyer  c Theekshana b Madushanka    82     56       84   3   6
# 4      KL Rahul      c Hemantha b Chameera    21     19       34   2   0
#
#    strike_rate   team   opponent  innings  match_id
# 0       200.00  India  Sri Lanka        1         0
# 1       100.00  India  Sri Lanka        1         0
# 2        93.61  India  Sri Lanka        1         0
# 3       146.42  India  Sri Lanka        1         0
# 4       110.52  India  Sri Lanka        1         0

# %%
prev_bat.isnull().sum()
# Out:
# player         0
# dismissal      0
# runs           0
# balls          0
# minutes        0
# 4s             0
# 6s             0
# strike_rate    0
# team           0
# opponent       0
# innings        0
# match_id       0
# dtype: int64

# %%
prev_bat['player'].value_counts()
# Out:
# player
# Rohit Sharma          11
# Virat Kohli           11
# Shreyas Iyer          11
# David Warner          11
# Steven Smith          10
#                       ..
# Hardik Pandya          1
# Ryan Klein             1
# Usama Mir              1
# Andile Phehlukwayo     1
# Agha Salman            1
# Name: count, Length: 146, dtype: int64

# %%
player_stats = prev_bat.groupby('player').agg(
     team=('team', 'first'),
    total_runs=('runs', 'sum'),
    avg_runs=('runs', 'mean'),
    avg_strikerate=('strike_rate', 'mean'),
    total_4s=('4s', 'sum'),
    total_6s=('6s', 'sum'),
    innings_count=('innings', 'count')
).reset_index()

# Display the result
print(player_stats)
# Out:
#                 player          team  total_runs   avg_runs  avg_strikerate  \
# 0    Abdullah Shafique      Pakistan         336  42.000000       71.400000
# 1           Adam Zampa     Australia          48   8.000000       75.230000
# 2          Adil Rashid       England          92  10.222222       91.631111
# 3          Agha Salman      Pakistan          51  51.000000      113.330000
# 4        Aiden Markram  South Africa         406  40.600000      151.525000
# ..                 ...           ...         ...        ...             ...
# 141          Usama Mir      Pakistan           0   0.000000        0.000000
# 142    Vikramjit Singh   Netherlands          98  16.333333       52.366667
# 143        Virat Kohli         India         765  69.545455       83.206364
# 144     Wesley Barresi   Netherlands          83  20.750000       66.167500
# 145         Will Young   New Zealand         206  34.333333       68.415000
#
#      total_4s  total_6s  innings_count
# ...

# %%
player_stats.to_pickle("player_stats.pkl")

# %%
player_stats.to_csv('player_stats.csv', index=False)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.parse import urljoin

# Function to fetch player image URL from Cricbuzz
def get_player_image_url(player_name):
    # Replace spaces with hyphens for URL formation
    search_query = player_name.replace(' ', '-').lower()
    url = f'https://www.cricbuzz.com/profiles/{search_query}'

    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }

    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Try to find the image tag that contains the player's image on Cricbuzz
    img_tag = soup.find('img', {'class': 'cb-col cb-col-33 cb-ltst-wgt-hdr'})
    if img_tag and 'src' in img_tag.attrs:
        img_url = img_tag['src']
        # Ensure the URL is absolute
        absolute_url = urljoin('https:', img_url)
        return absolute_url
    return None

# Read player stats CSV (replace 'player_stats.csv' with your file path)
df1 = pd.read_csv('player_stats.csv')

# Check if the 'player_image' column exists; if not, add it
if 'player_image' not in df1.columns:
    # Add player image URLs
    df1['player_image'] = df1['player'].apply(get_player_image_url)

    # Save updated CSV with the player_image column
    df1.to_csv('player_stats_with_images.csv', index=False)
    print("Updated CSV saved with player_image column.")
else:
    print("'player_image' column already exists.")
# Out:
# Updated CSV saved with player_image column.

# %%
image = pd.read_csv('player_stats_with_images.csv')

# %%
image
# Out:
#                 player          team  total_runs   avg_runs  avg_strikerate  \
# 0    Abdullah Shafique      Pakistan         336  42.000000       71.400000
# 1           Adam Zampa     Australia          48   8.000000       75.230000
# 2          Adil Rashid       England          92  10.222222       91.631111
# 3          Agha Salman      Pakistan          51  51.000000      113.330000
# 4        Aiden Markram  South Africa         406  40.600000      151.525000
# ..                 ...           ...         ...        ...             ...
# 141          Usama Mir      Pakistan           0   0.000000        0.000000
# 142    Vikramjit Singh   Netherlands          98  16.333333       52.366667
# 143        Virat Kohli         India         765  69.545455       83.206364
# 144     Wesley Barresi   Netherlands          83  20.750000       66.167500
# 145         Will Young   New Zealand         206  34.333333       68.415000
#
#      total_4s  total_6s  innings_count  player_image
# ...

# %%
image.to_pickle("player_stats1.pkl")

# %%
prev_bowl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   player    574 non-null    object
#  1   overs     574 non-null    float64
#  2   maidens   574 non-null    int64
#  3   runs      574 non-null    int64
#  4   wickets   574 non-null    int64
#  5   run_rate  574 non-null    float64
#  6   0s        574 non-null    int64
#  7   4s        574 non-null    int64
#  8   6s        574 non-null    int64
#  9   wd        574 non-null    int64
#  10  nb        574 non-null    int64
#  11  team      574 non-null    object
#  12  opponent  574 non-null    object
#  13  innings   574 non-null    int64
#  14  match_id  574 non-null    int64
# dtypes: float64(2), int64(10), object(3)
# memory usage: 67.4+ KB

# %%
prev_bowl.head()
# Out:
#                 player  overs  maidens  runs  wickets  run_rate  0s  4s  6s  \
# 0   Dilshan Madushanka   10.0        0    80        5      8.00  25   8   2
# 1  Dushmantha Chameera   10.0        2    71        1      7.10  28   8   2
# 2        Kasun Rajitha    9.0        0    65        0      7.22  25   7   2
# 3       Angelo Mathews    3.0        0    11        0      3.66  10   1   0
# 4   Maheesh Theekshana   10.0        0    67        0      6.70  18   5   1
#
#    wd  nb       team opponent  innings  match_id
# 0   6   0  Sri Lanka    India        1         0
# 1   0   0  Sri Lanka    India        1         0
# 2   1   0  Sri Lanka    India        1         0
# 3   0   0  Sri Lanka    India        1         0
# 4   1   0  Sri Lanka    India        1         0

# %%
prev_bowl.isnull().sum()
# Out:
# player      0
# overs       0
# maidens     0
# runs        0
# wickets     0
# run_rate    0
# 0s          0
# 4s          0
# 6s          0
# wd          0
# nb          0
# team        0
# opponent    0
# innings     0
# match_id    0
# dtype: int64

# %%
bowl_stats = prev_bowl.groupby('player').agg(
    team=('team', 'first'),
    total_runs1=('runs', 'sum'),
    total_overs=('overs', 'sum'),
    total_maiden=('maidens', 'sum'),
    total_wicket=('wickets','sum'),
    avg_runrate=('run_rate', 'mean'),
    matches=('innings', 'count')
).reset_index()

print(bowl_stats)
# Out:
#                  player          team  total_runs1  total_overs  total_maiden  \
# 0            Adam Zampa     Australia          515         96.0             1
# 1           Adil Rashid       England          413         79.4             1
# 2           Agha Salman      Pakistan           46          5.0             0
# 3         Aiden Markram  South Africa           85         18.3             1
# 4    Andile Phehlukwayo  South Africa           36          7.0             0
# ..                  ...           ...          ...          ...           ...
# 97          Travis Head     Australia          101         21.0             0
# 98          Trent Boult   New Zealand          504         91.0             6
# 99            Usama Mir      Pakistan          248         35.0             0
# 100     Vikramjit Singh   Netherlands           52          7.0             0
# 101         Virat Kohli         India           15          3.3             0
#
# ...

# %%
bowl_stats.to_pickle("bowl_stats.pkl")

# %%
bowl_stats.to_csv('bowl_stats.csv', index=False)

# %%
image1 = pd.read_pickle("bowl_stats.pkl")

# Check the first few rows of the data
print(image1.head())
# Out:
#                player          team  total_runs1  total_overs  total_maiden  \
# 0          Adam Zampa     Australia          515         96.0             1
# 1         Adil Rashid       England          413         79.4             1
# 2         Agha Salman      Pakistan           46          5.0             0
# 3       Aiden Markram  South Africa           85         18.3             1
# 4  Andile Phehlukwayo  South Africa           36          7.0             0
#
#    total_wicket  avg_runrate  matches
# 0            23     5.290909       11
# 1            15     5.456667        9
# 2             0     9.415000        2
# 3             1     5.480000        4
# 4             1     5.140000        1
